# %%
import pandas as pd

# %%
gex = pd.read_csv('/Users/dana/Desktop/AHI/01_PAML/Project/data/mammacarcinoma_gex.csv', index_col=0)

# %%
gex
# Out:
#                DDR1    RFC2   HSPA6    PAX8   GUCA1A    THRA  PTPN21   EPHB3  \
# patient_id
# 0            9.2048  6.3038  7.7602  7.9725  4.26530  2.9992  3.6423  6.9242
# 1           10.0090  5.8149  6.7343  7.9232  3.50110  5.2618  4.3622  6.9789
# 2            8.6175  5.9355  5.8762  6.5176  2.53460  6.0643  4.6878  7.2233
# 3            9.6734  7.0122  5.5486  8.0859  4.28850  4.9998  2.9966  6.1568
# 4            9.0900  6.0937  6.6429  7.9868  3.27290  5.4990  2.0513  6.7127
# ...             ...     ...     ...     ...      ...     ...     ...     ...
# 322          9.6058  5.6191  6.8271  7.8933  5.17700  4.8729  4.7611  6.7124
# 323          9.5777  6.1209  6.1702  6.9966  4.01260  5.5290  3.0468  7.0455
# 324          8.7979  5.2583  5.8413  7.7988  4.92420  4.5145  4.4398  6.7248
# 325          9.5556  6.8688  5.9040  7.7559  3.94300  4.7437  3.1722  6.8635
# 326          8.6473  6.5826  5.3523  5.9178  0.33588  6.0855  4.1776  6.8928
#
# ...

# %%
llm_genes = ['ESR1',
'PGR',
'GATA3',
'FOXA1',
'XBP1',
'TFF1',
'MKI67',
'AURKA',
'CCNB1',
'ERBB2',
'EGFR',
'VIM',
'CDH1',
'FOXC1',
'KRT5',
'KRT14',
'MAPT',
'NAT1']

# %%
len(llm_genes)
# Out:
# 18

# %%
gex.columns
# Out:
# Index(['DDR1', 'RFC2', 'HSPA6', 'PAX8', 'GUCA1A', 'THRA', 'PTPN21', 'EPHB3',
#        'ESRRA', 'CYP2A6',
#        ...
#        'CASP8AP2', 'POLM', 'KLK5', 'SH3BP4', 'SPO11', 'TRDN', 'DKFZP564C196',
#        'YDD19', 'TAZ', 'GMEB2'],
#       dtype='object', length=6384)

# %%
llm_genes_in_dataset = []

for gene in gex.columns:
    if gene in llm_genes:
        print(gene)
        llm_genes_in_dataset.append(gene)

len(llm_genes_in_dataset)
# Out:
# XBP1
# CDH1
# VIM
# KRT5
# EGFR
# MAPT
# TFF1
# ESR1
# PGR
# KRT14
# GATA3
# ERBB2
# MKI67
# FOXC1
# NAT1
# CCNB1
# 16

# %%
llm_genes_in_dataset
# Out:
# ['XBP1',
#  'CDH1',
#  'VIM',
#  'KRT5',
#  'EGFR',
#  'MAPT',
#  'TFF1',
#  'ESR1',
#  'PGR',
#  'KRT14',
#  'GATA3',
#  'ERBB2',
#  'MKI67',
#  'FOXC1',
#  'NAT1',
#  'CCNB1']

# %%
set(llm_genes) - set(llm_genes_in_dataset)
# Out:
# {'AURKA', 'FOXA1'}
